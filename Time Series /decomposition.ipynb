# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Load the dataset
data = pd.read_csv("AirPassengers.csv")

# %%
data.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       144 non-null    object
#  1   Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
data.describe()
# Out:
#        Passengers
# count  144.000000
# mean   280.298611
# std    119.966317
# min    104.000000
# 25%    180.000000
# 50%    265.500000
# 75%    360.500000
# max    622.000000

# %%
# Convert the data into datatime datatype. If we don't set the index and change the datatype for the data, it will throw error.
data['Month'] = pd.to_datetime(data['Month'])
data.set_index('Month', inplace=True)

# %%
result = seasonal_decompose(data, model='multiplicative')

# %%
result.plot();

# %%
result_1 = seasonal_decompose(data, model='additive')

# %%
result_1.plot();

# %% [markdown]
# However, we will choose the multiplicative decomposition as there is an increase in the trend and also an increase in the seasonality of the data
